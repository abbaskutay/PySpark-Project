# %%
pip install plotly
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: plotly in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e401340c-cd8a-4e28-9d91-849acc3f685f/lib/python3.7/site-packages (4.14.3)
# Requirement already satisfied: six in /databricks/python3/lib/python3.7/site-packages (from plotly) (1.14.0)
# Requirement already satisfied: retrying&gt;=1.3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e401340c-cd8a-4e28-9d91-849acc3f685f/lib/python3.7/site-packages (from plotly) (1.3.3)
# Python interpreter will be restarted.
# </div>

# %%
pip install plotly-express
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Collecting plotly-express
#   Using cached plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: plotly&gt;=4.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e401340c-cd8a-4e28-9d91-849acc3f685f/lib/python3.7/site-packages (from plotly-express) (4.14.3)
# Requirement already satisfied: patsy&gt;=0.5 in /databricks/python3/lib/python3.7/site-packages (from plotly-express) (0.5.1)
# Requirement already satisfied: statsmodels&gt;=0.9.0 in /databricks/python3/lib/python3.7/site-packages (from plotly-express) (0.11.0)
# Requirement already satisfied: scipy&gt;=0.18 in /databricks/python3/lib/python3.7/site-packages (from plotly-express) (1.4.1)
# Requirement already satisfied: pandas&gt;=0.20.0 in /databricks/python3/lib/python3.7/site-packages (from plotly-express) (1.0.1)
# Requirement already satisfied: numpy&gt;=1.11 in /databricks/python3/lib/python3.7/site-packages (from plotly-express) (1.18.1)
# Requirement already satisfied: python-dateutil&gt;=2.6.1 in /databricks/python3/lib/python3.7/site-packages (from pandas&gt;=0.20.0-&gt;plotly-express) (2.8.1)
# Requirement already satisfied: pytz&gt;=2017.2 in /databricks/python3/lib/python3.7/site-packages (from pandas&gt;=0.20.0-&gt;plotly-express) (2019.3)
# Requirement already satisfied: six in /databricks/python3/lib/python3.7/site-packages (from patsy&gt;=0.5-&gt;plotly-express) (1.14.0)
# Requirement already satisfied: retrying&gt;=1.3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e401340c-cd8a-4e28-9d91-849acc3f685f/lib/python3.7/site-packages (from plotly&gt;=4.1.0-&gt;plotly-express) (1.3.3)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1
# Python interpreter will be restarted.
# </div>

# %%
from pyspark.sql import SQLContext
import pyspark.sql.functions as F
from pyspark.sql.functions import *
sqCon = SQLContext(sc)
df1 = sqCon.read.format('csv').load("/FileStore/tables/output1.csv",header=True,inferSchema=True)
df2 = sqCon.read.format('csv').load('/FileStore/tables/output2.csv',header=False,inferSchema=True)
df3 = sqCon.read.format('csv').load('/FileStore/tables/output3.csv',header=False,inferSchema=True)
df4 = sqCon.read.format('csv').load('/FileStore/tables/output4.csv',header=False,inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfUnion = df1.union(df2).union(df3).union(df4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = dfUnion.select('country_code','country_name','year','sex','max_age','age','population').dropDuplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h3>
# <ul>
#   <li>From past to present show highest population increase among all countries</li>
# </ul>
# </h3>

# %%
df_midyear_population = spark.read.format("csv").option("header", "true").load("/FileStore/tables/midyear_population.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import IntegerType
# df_midyear_population = df_midyear_population.withColumn("year", df_midyear_population["year"].cast(IntegerType())
df_midyear_population = df_midyear_population.withColumn("year", df_midyear_population["year"].cast(IntegerType()))\
  .withColumn('midyear_population',df_midyear_population['midyear_population'].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
past_population = df_midyear_population.filter(df_midyear_population["year"] == 1950).withColumnRenamed('midyear_population',"Population in 1950").select('country_name','Population in 1950')
present_population = df_midyear_population.filter(df_midyear_population["year"] == 2020).withColumnRenamed('midyear_population',"Population in 2020").select('country_name','Population in 2020')
pop_increase = past_population.join(present_population,(past_population.country_name==present_population.country_name),"full").drop(present_population['country_name'])
pop_increase = pop_increase.withColumn('Population Increase', col('Population in 2020')-col('Population in 1950')).sort("Population Increase", ascending=False)
# display(pop_increase.limit(3))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import plotly.express as px 
fig = px.bar(pop_increase.toPandas(), x='country_name', y='Population Increase', height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="7f8136b6-5e7d-4cce-93a0-ad7b36d452c5" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f8136b6-5e7d-4cce-93a0-ad7b36d452c5")) {                    Plotly.newPlot(                        "7f8136b6-5e7d-4cce-93a0-ad7b36d452c5",                        [{"alignmentgroup": "True", "hovertemplate": "country_name=%{x}<br>Population Increase=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["India", "China", "Indonesia", "United States", "Pakistan", "Nigeria", "Brazil", "Bangladesh", "Mexico", "Ethiopia", "Philippines", "Egypt", "Congo (Kinshasa)", "Vietnam", "Iran", "Turkey", "Tanzania", "Thailand", "Kenya", "South Africa", "Japan", "Russia", "Burma", "Uganda", "Colombia", "Iraq", "Algeria", "Sudan", "Korea South", "Afghanistan", "Argentina", "Venezuela", "Malaysia", "Saudi Arabia", "Morocco", "France", "Yemen", "Peru", "Uzbekistan", "Ghana", "Cote d'Ivoire", "Canada", "Mozambique", "Madagascar", "Cameroon", "Spain", "Nepal", "Syria", "Malawi", "Angola", "Niger", "Burkina Faso", "Korea North", "Mali", "Australia", "United Kingdom", "Taiwan", "Sri Lanka", "Italy", "Zambia", "Ecuador", "Poland", "Guatemala", "Senegal", "Zimbabwe", "Cambodia", "Kazakhstan", "Chile", "Rwanda", "South Sudan", "Germany", "Guinea", "Benin", "Burundi", "Chad", "Somalia", "Bolivia", "Dominican Republic", "Honduras", "Tunisia", "Haiti", "Togo", "Israel", "Tajikistan", "Azerbaijan", "Netherlands", "Ukraine", "Jordan", "United Arab Emirates", "Libya", "Papua New Guinea", "Paraguay", "Laos", "Cuba", "Singapore", "Nicaragua", "Hong Kong", "Romania", "Central African Republic", "Eritrea", "Sierra Leone", "Congo (Brazzaville)", "Turkmenistan", "El Salvador", "Costa Rica", "Kyrgyzstan", "Lebanon", "Liberia", "Switzerland", "Sweden", "Greece", "Oman", "Belgium", "Panama", "Mauritania", "Kuwait", "New Zealand", "Qatar", "Portugal", "Mongolia", "Ireland", "Norway", "Namibia", "West Bank", "Slovakia", "Austria", "Gambia The", "Botswana", "Albania", "Czechia", "Belarus", "Gaza Strip", "Jamaica", "Armenia", "Finland", "Gabon", "Georgia", "Bahrain", "Denmark", "Guinea-Bissau", "Puerto Rico", "Lesotho", "Swaziland", "Uruguay", "Bosnia and Herzegovina", "Kosovo", "Serbia", "Moldova", "Timor-Leste", "Mauritius", "Macedonia", "Djibouti", "Cyprus", "Comoros", "Fiji", "Western Sahara", "Equatorial Guinea", "Bhutan", "Solomon Islands", "Trinidad and Tobago", "Slovenia", "Cabo Verde", "Hungary", "Brunei", "Macau", "Suriname", "Croatia", "Luxembourg", "Guyana", "Belize", "Maldives", "Bahamas The", "Vanuatu", "Montenegro", "New Caledonia", "French Polynesia", "Iceland", "Lithuania", "Sao Tome and Principe", "Estonia", "Samoa", "Guam", "Malta", "Saint Lucia", "Barbados", "Andorra", "Kiribati", "Virgin Islands U.S.", "Micronesia Federated States of", "Aruba", "Marshall Islands", "Seychelles", "Tonga", "Cayman Islands", "Antigua and Barbuda", "Northern Mariana Islands", "Turks and Caicos Islands", "Curacao", "Jersey", "Sint Maarten", "Grenada", "Isle of Man", "Greenland", "Saint Vincent and the Grenadines", "American Samoa", "Bermuda", "Virgin Islands British", "Saint Martin", "Liechtenstein", "Dominica", "Guernsey", "San Marino", "Faroe Islands", "Palau", "Anguilla", "Monaco", "Saint Kitts and Nevis", "Wallis and Futuna", "Tuvalu", "Gibraltar", "Nauru", "Saint Barthelemy", "Saint Helena", "Saint Pierre and Miquelon", "Cook Islands", "Montserrat", "Latvia", "Bulgaria"], "xaxis": "x", "y": [956213247, 831436198, 184047974, 182635458, 173337265, 173112281, 158272898, 117004889, 100164385, 94465672, 88049551, 82926749, 75680973, 73373131, 70186402, 60895875, 5 ...

# %% [markdown]
# <h3>
# <ul>
#   <li>Compare to years, highest life expectancy increase among countries</li>
# </ul>
# </h3>

# %%
df_mortality_life_expectancy = spark.read.format("csv").option("header", "true").load("/FileStore/tables/mortality_life_expectancy.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ans = df_mortality_life_expectancy.filter((col("year") >='2000') & (col("year") <="2020")) \
  .groupBy('country_name') \
  .agg(F.avg('life_expectancy').alias('Life Expectancy')) \
  .sort('Life Expectancy',ascending = False)

# display(ans)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h3>
# <ul>
#   <li>Average age in a country that have a high life expectancy</li>
# </ul>
# </h3>

# %%
q3 = df.filter((col("year") >='2000') & (col("year") <="2020")).filter(col("age") > 0).groupBy('country_name','age').agg(F.sum('population').alias('population'))
q3 = q3.withColumn('mean of age', col('age') * col('population'))
q3 = q3.groupBy('country_name').sum().select('country_name','sum(population)','sum(mean of age)')
q3 = q3.withColumn("Average Age", col('sum(mean of age)') / col('sum(population)')).drop('sum(population)','sum(mean of age)')
answer = q3.join(ans,(q3.country_name == ans.country_name), 'full').drop(ans['country_name']).sort("Average Age", ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
answer.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+------------------+-----------------+
# country_name|       Average Age|  Life Expectancy|
# +------------+------------------+-----------------+
#       Monaco| 47.88725733501263|89.02190476190476|
#        Japan|44.490354355178624|83.42619047619048|
#        Italy| 43.35139107683986| 81.4695238095238|
#      Germany| 43.31169513153365|79.81857142857143|
#       Greece| 42.54557792929272|            79.74|
#     Slovenia| 41.76211949721336|77.05047619047619|
#   San Marino| 41.74168576435178|82.72238095238097|
#      Austria| 41.62992601077673|80.48238095238096|
#  Isle of Man| 41.62525562519566|80.12285714285716|
#     Guernsey| 41.56461578885861|81.61142857142858|
#     Bulgaria| 41.48977247780416|73.22714285714287|
#      Finland| 41.23805891287306|79.79571428571428|
#        Spain|41.224856354371134|80.87904761904761|
#      Croatia|41.192786450170686| 74.9947619047619|
#       Sweden| 41.09711196863328|81.26238095238095|
#       Serbia|41.086661504874506|74.10619047619048|
#  Switzerland|  41.0707432142198|81.74380952380953|
#       Latvia|40.971302151922664|72.50666666666669|
#      Estonia|  40.8971483798696| 74.3442857142857|
#      Belgium|40.894181466166145| 79.8652380952381|
# +------------+------------------+-----------------+
# only showing top 20 rows
#
# </div>

# %%
answerplt= answer.toPandas()
answerplt.plot(x='Life Expectancy', y='Average Age', kind='scatter')
display()

# %% [markdown]
# <h3>
# <ul>
#   <li>Infant mortality rate in a country that have a high life expectancy.</li>
# </ul>
# </h3>

# %%
inf = df_mortality_life_expectancy.filter(df_mortality_life_expectancy['year'].isin(2000))
inf = inf.select(inf["country_name"],inf["year"],inf["infant_mortality"],inf["life_expectancy"])
infant_mortality = inf.sort("infant_mortality", ascending=False)
display(infant_mortality)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_name</th><th>year</th><th>infant_mortality</th><th>life_expectancy</th></tr></thead><tbody><tr><td>Ethiopia</td><td>2000</td><td>99.31</td><td>51.81</td></tr><tr><td>Equatorial Guinea</td><td>2000</td><td>99.16</td><td>58.42</td></tr><tr><td>Burkina Faso</td><td>2000</td><td>99.00</td><td>48.87</td></tr><tr><td>Congo (Kinshasa)</td><td>2000</td><td>98.40</td><td>51.80</td></tr><tr><td>Gambia The</td><td>2000</td><td>94.55</td><td>59.60</td></tr><tr><td>Burundi</td><td>2000</td><td>91.96</td><td>49.24</td></tr><tr><td>Rwanda</td><td>2000</td><td>90.75</td><td>46.44</td></tr><tr><td>Belarus</td><td>2000</td><td>9.37</td><td>69.06</td></tr><tr><td>Hungary</td><td>2000</td><td>9.34</td><td>71.51</td></tr><tr><td>Qatar</td><td>2000</td><td>9.16</td><td>75.76</td></tr><tr><td>Chile</td><td>2000</td><td>9.12</td><td>75.98</td></tr><tr><td>Comoros</td><td>2000</td><td>89.67</td><td>58.77</td></tr><tr><td>Guinea</td><td>2000</td><td>87.46</td><td>52.10</td></tr><tr><td>Pakistan</td><td>2000</td><td>86.99</td><td>61.85</td></tr><tr><td>Malawi</td><td>2000</td
# %% [markdown]
# <h3>
# <ul>
#   <li>CRUDE BIRTH RATE ON WORLD MAP</li>
# </ul>
# </h3>

# %%
import numpy as np # linear algebra
import pandas as pd
from pyspark.sql import SQLContext
import pyspark.sql.functions as F
from pyspark.sql.functions import *
sqCon = SQLContext(sc)
# df_birth_death_growth_rates = pd.read_csv("/dbfs/FileStore/tables/birth_death_growth_rates.csv")
df_birth_death_growth_rates = sqCon.read.format("csv").load("/FileStore/tables/birth_death_growth_rates.csv",header='true')
df_birth_death_growth_rates = df_birth_death_growth_rates.withColumnRenamed('country_name', 'Country')

df_covid = sqCon.read.format("csv").load("/FileStore/tables/COVID19_son1.csv",header='true')
df_covid = df_covid.withColumnRenamed('Country/Region', 'Country')
df_covid = df_covid.select(['Country','Lat','Long'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_birth_death_growth_rates = df_birth_death_growth_rates.join(df_covid,(df_birth_death_growth_rates.Country == df_covid.Country), 'full').drop(df_covid['Country'])
new = df_birth_death_growth_rates.filter(df_birth_death_growth_rates['Lat'].isNotNull())
# display(new.select('Country').dropDuplicates())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# !pip install plotly
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: plotly in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e401340c-cd8a-4e28-9d91-849acc3f685f/lib/python3.7/site-packages (4.14.3)
# Requirement already satisfied: six in /databricks/python3/lib/python3.7/site-packages (from plotly) (1.14.0)
# Requirement already satisfied: retrying&gt;=1.3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e401340c-cd8a-4e28-9d91-849acc3f685f/lib/python3.7/site-packages (from plotly) (1.3.3)
# </div>

# %%
geo = new.groupBy("Lat","Long").agg(F.count(new['crude_birth_rate']).alias("crude_birth_rate"))
geo = geo.filter(geo['crude_birth_rate'].isNotNull())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# geo2 = df.groupBy('Lat','Long')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import plotly.graph_objects as go

def plot_map(dataframe,focusOn):
  fig = go.Figure(data=go.Scattergeo(
          lon = dataframe['Long'],
          lat = dataframe['Lat'],
          mode = 'markers',
          marker_color = dataframe[focusOn],
            marker = dict(
              size = 9,
              opacity = 0.8,
              reversescale = True,
              autocolorscale = True,
              symbol = 'square',
              line = dict(
                  width=2,
                  color='white'
              ),
              colorscale = 'teal',
              cmin = 0,
              color = dataframe[focusOn],
              cmax = dataframe[focusOn].max(),
              colorbar_title="The range of {}".format(focusOn))
          ))

  fig.update_layout(
    margin=dict(l=20, r=20, t=20, b=20),
          title = 'Plot',
      )
  fig.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plot_map(geo.toPandas(),'crude_birth_rate')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="5e643573-b842-4256-b956-6634273a5eb1" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e643573-b842-4256-b956-6634273a5eb1")) {                    Plotly.newPlot(                        "5e643573-b842-4256-b956-6634273a5eb1",                        [{"lat": ["63.0", "54.236107", "-15.3101", "50.8333", "128.0", "39.0639", "48.3794", "-15.3101", "41.2956", "-15.3101", "128.0", " 0.18636", "-15.376706", "35.5653", "-41.4545", "43.9159", "-15.3101", "12.865416", "17.0608", "13.1939", "33.882", "-17.6797", "39.3999", "56.8796", "38.8974", "-15.3101", "39
# %%
import plotly.express as px

turkey = df_birth_death_growth_rates.filter(df_birth_death_growth_rates['Country']== 'Turkey')
fig = px.bar(turkey.toPandas(), x='year', y='crude_birth_rate',
              height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="ea7b451d-48d3-45c5-ae2c-cc58d39a4b77" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea7b451d-48d3-45c5-ae2c-cc58d39a4b77")) {                    Plotly.newPlot(                        "ea7b451d-48d3-45c5-ae2c-cc58d39a4b77",                        [{"alignmentgroup": "True", "hovertemplate": "year=%{x}<br>crude_birth_rate=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2032", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2031", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2030", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2029", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2028", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "2027", "20 ...

# %%
import plotly.express as px

turkey = df.filter(df['country_name']== 'Turkey').filter(df['year'] == '2020')
fig = px.bar(turkey.toPandas(), x='age', y='population',
              height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="fe06cc6f-4cfd-49cf-8dc8-270f1703e37d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe06cc6f-4cfd-49cf-8dc8-270f1703e37d")) {                    Plotly.newPlot(                        "fe06cc6f-4cfd-49cf-8dc8-270f1703e37d",                        [{"alignmentgroup": "True", "hovertemplate": "age=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [22, 49, 29, 9, 62, 2, 57, 8, 97, 67, 13, 24, 30, 16, 67, 72, 46, 81, 90, 33, 26, 6, 33, 4, 27, 12, 94, 17, 77, 78, 76, 60, 86, 21, 44, 96, 15, 32, 7, 56, 66, 75, 59, 79, 81, 14, 87, 7, 95, 82, 98, 11, 79, 14, 23, 34, 88, 54, 42, 77, 39, 16, 74, 90, 91, 92, 84, 0, 75, 55, 96, 62, 51, 52, 76, 43, 25, 54, 71, 51, 17, 87, 70, 3, 5, 84, 39, 92, 46, 19, 20, 63, 44, 10, 89, 35, 93, 9, 20, 73, 70, 57, 73, 58, 11, 99, 22, 68, 36, 74, 83, 1, 85, 80, 5, 83, 48, 63, 52, 30, 58, 82, 38, 68, 59, 55, 61, 1, 28, 88, 69, 94, 69, 42, 53, 93, 53, 65, 31, 91, 45, 37, 35, 49, 97, 86, 41, 38, 43, 8, 48, 23, 32, 28, 71, 18, 15, 50, 13, 10, 99, 80, 40, 2, 27, 6, 3, 60, 100, 47, 72, 24, 64, 100, 36, 50, 21, 41, 37, 56, 18, 66, 61, 12, 0, 64, 65, 4, 95, 31, 98, 19, 78, 47, 40, 29, 26, 85, 45, 25, 89, 34], "xaxis": "x", "y": [641577, 523707, 629032, 643009, 340405, 596091, 425861, 667807, 582, 255832, 683375, 630676, 633240, 676447, 274654, 193241, 556921, 61383, 27012, 641925, 619201, 622444, 623039, 605921, 619253, 650274, 2542, 671993, 130402, 121564, 140922, 374941, 54222, 646534, 586049, 986, 680429, 639903, 630077, 433276, 272211, 153047, 388450, 78700, 98703, 651681, 25551, 659885, 5471, 54046, 1332, 679434, 113815, 682643, 612189, 631063, 20182, 454362, 599216, 98369, 691242, 645545, 165857, 11298, 8151, 5706, 41905, 587457, 124176, 442934, 3488, 332852, 493992, 480018, 110474, 596519, 603467, 449590, 187350, 481647, 641367, 46335, 203863, 628750, 614021, 72104, 670345, 16588, 565911, 660409, 652819, 326496, 576270, 678041, 15322, 664769, 3875, 673334, 625170, 179015, 224860, 421108, 154790, 405914, 648654, 809, 616199, 258738, 676645, 139130, 81411, 619483, 62871, 69797, 643136, 47706, 539142, 317196, 468272, 615921, 411452, 90416, 693857, 238624, 393932, 443477, 356843, 591416, 624506, 39277, 241848, 8312, 221038, 611074, 466830, 12062, 457888, 302065, 619078, 21624, 567292, 665434, 644722, 513586, 2164, 31028, 618746, 672920, 585931, 637675, 529819, 636325, 621463, 606969, 208647, 667054, 649528, 497449, 652322, 647458, 182, 106424, 647435, 624400, 600577, 651933, 600267, 369371, 198, 544433, 170976, 607889, 314187, 1085, 656162, 508994, 620018, 632776, 686194, 435895, 637139, 288953, 350508, 681205, 615468, 302726, 287969, 634659, 1611, 636972, 330, 631571, 87930, 553385, 665686, 612047, 599255, 36445, 576570, 624849, 32836, 650500], "yaxis": "y"}],                        {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, " ...

# %%
# df_midyear_population.groupBy('country_name').agg(F.sum('midyear_population')).show()
# # df_midyear_population.dropDuplicates().show()

a = df_midyear_population.filter(df_midyear_population['year']<2021).groupBy('year').agg(F.avg('midyear_population')).withColumn("midyear_population", col("avg(midyear_population)").cast("Integer")).drop('avg(midyear_population)')

a.show()

b = df_midyear_population.filter(df_midyear_population['year']>2021).groupBy('year').agg(F.avg('midyear_population')).withColumn("midyear_population", col("avg(midyear_population)").cast("Integer")).drop('avg(midyear_population)')

b.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+------------------+
# year|midyear_population|
# +----+------------------+
# 1959|          13161037|
# 1990|          23172162|
# 1975|          17930035|
# 1977|          18547731|
# 2003|          27690304|
# 2007|          29043390|
# 2018|          32798051|
# 1974|          17616638|
# 2015|          31777630|
# 1955|          12202188|
# 2006|          28701700|
# 1978|          18858494|
# 1961|          13526170|
# 2013|          31098394|
# 1952|          11564790|
# 1956|          12435524|
# 1997|          25676927|
# 1988|          22402662|
# 1994|          24625850|
# 1968|          15624183|
# +----+------------------+
# only showing top 20 rows
#
# +----+------------------+
# year|midyear_population|
# +----+------------------+
# 2025|          35040723|
# 2027|          35635068|
# 2035|          37810751|
# 2044|          39915352|
# 2032|          37030612|
# 2023|          34425336|
# 2047|          40536985|
# 2022|          34109723|
# 2031|          36761345|
# 2042|          39477863|
# 2038|          38551062|
# 2037|          38308511|
# 2045|          40127125|
# 2040|          39023036|
# 2026|          35340400|
# 2041|          39252520|
# 2036|          38061713|
# 2048|          40734959|
# 2029|          36208651|
# 2046|          40334307|
# +----+------------------+
# only showing top 20 rows
#
# </div>

# %%
import plotly.express as px

fig = px.bar(a.toPandas(), x='year', y='midyear_population',color='year',
              height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id
"coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2025, 2027, 2035, 2044, 2032, 2023, 2047, 2022, 2031, 2042, 2038, 2037, 2045, 2040, 2026, 2041, 2036, 2048, 2029, 2046, 2030, 2034, 2033, 2050, 2043, 2039, 2028, 2024, 2049], "xaxis": "x", "y": [35040723, 35635068, 37810751, 39915352, 37030612, 34425336, 40536985, 34109723, 36761345, 39477863, 38551062, 38308511, 40127125, 39023036, 35340400, 39252520, 38061713, 40734959, 36208651, 40334307, 36487483, 37555367, 37295295, 41116158, 39698874, 38789270, 35924502, 34735790, 40928063], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "midyear_population"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 400, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], ...

# %%
frame = sqCon.read.format('csv').load("/FileStore/tables/midyear_population_age_sex.csv",header=True,inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.withColumn('sex',F.when(df['sex']=='Female',0).otherwise(1))
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_code</th><th>country_name</th><th>year</th><th>sex</th><th>max_age</th><th>age</th><th>population</th></tr></thead><tbody><tr><td>ES</td><td>El Salvador</td><td>2046</td><td>0</td><td>100</td><td>27</td><td>36540</td></tr><tr><td>CV</td><td>Cabo Verde</td><td>2033</td><td>0</td><td>100</td><td>74</td><td>1763</td></tr><tr><td>GV</td><td>Guinea</td><td>1978</td><td>1</td><td>97</td><td>42</td><td>17973</td></tr><tr><td>BD</td><td>Bermuda</td><td>2041</td><td>0</td><td>100</td><td>11</td><td>385</td></tr><tr><td>MZ</td><td>Mozambique</td><td>1989</td><td>1</td><td>100</td><td>24</td><td>98708</td></tr><tr><td>TW</td><td>Taiwan</td><td>1994</td><td>1</td><td>100</td><td>2</td><td>165565</td></tr><tr><td>SL</td><td>Sierra Leone</td><td>2000</td><td>1</td><td>100</td><td>40</td><td>14235</td></tr><tr><td>RS</td><td>Russia</td><td>2045</td><td>1</td><td>100</td><td>10</td><td>650473</td></tr><tr><td>BX</td><td>Brunei</td><td>1991</td><td>1</td><td>100</td><td>10</td><td>2979</td></tr><tr><td>GR</td><td>Greece</td><td>2032</td><td>1</td><td>100</td><td>1</td><td>44906</td></tr></tbody></table></div>

# %%
from pyspark.ml.feature import VectorAssembler
assembler = VectorAssembler(inputCols=['year','sex','age','population'],outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.withColumn("country_code", df["country_code"].cast('string'))\
        .withColumn("country_name", df["country_name"].cast('string'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output = assembler.transform(df)
output.show()
# display(output.select('Churn'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+--------------------+----+---+-------+---+----------+--------------------+
# country_code|        country_name|year|sex|max_age|age|population|            features|
# +------------+--------------------+----+---+-------+---+----------+--------------------+
#           GM|             Germany|2002|  1|    100| 13|    493198|[2002.0,1.0,13.0,...|
#           BT|              Bhutan|2023|  0|    100| 26|      6906|[2023.0,0.0,26.0,...|
#           ES|         El Salvador|2021|  1|    100| 57|     23018|[2021.0,1.0,57.0,...|
#           MK|           Macedonia|1998|  0|    100| 90|       285|[1998.0,0.0,90.0,...|
#           TO|                Togo|2038|  0|    100|  4|    156354|[2038.0,0.0,4.0,1...|
#           CH|               China|2038|  0|    100| 16|   7273714|[2038.0,0.0,16.0,...|
#           GY|              Guyana|2024|  0|    100| 40|      4153|[2024.0,0.0,40.0,...|
#           BD|             Bermuda|2029|  0|    100| 95|        64|[2029.0,0.0,95.0,...|
#           TN|               Tonga|2036|  0|    100| 47|       559|[2036.0,0.0,47.0,...|
#           BK|Bosnia and Herzeg...|2004|  0|    100| 31|     30761|[2004.0,0.0,31.0,...|
#           BR|              Brazil|1990|  0|    100| 50|    581936|[1990.0,0.0,50.0,...|
#           TP|Sao Tome and Prin...|2000|  0|    100| 44|       496|[2000.0,0.0,44.0,...|
#           UZ|          Uzbekistan|2043|  0|    100| 28|    224120|[2043.0,0.0,28.0,...|
#           NU|           Nicaragua|1979|  0|    100| 53|      7075|[1979.0,0.0,53.0,...|
#           MK|           Macedonia|2026|  1|    100| 38|     16394|[2026.0,1.0,38.0,...|
#           CO|            Colombia|2041|  0|    100| 18|    353541|[2041.0,0.0,18.0,...|
#           NP|               Nepal|1994|  1|    100| 12|    250034|[1994.0,1.0,12.0,...|
#           SB|Saint Pierre and ...|2025|  0|    100| 80|        28|[2025.0,0.0,80.0,...|
#           TS|             Tunisia|2002|  1|    100| 14|    104555|[2002.0,1.0,14.0,...|
#           IZ|                Iraq|2004|  0|    100| 68|     26960|[2004.0,0.0,68.0,...|
# +------------+--------------------+----+---+-------+---+----------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
final_data = output.select('features','sex')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_sex,test_sex = final_data.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.classification import LogisticRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr_sex = LogisticRegression(labelCol='sex')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fitted_sex_model = lr_sex.fit(train_sex)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_sum = fitted_sex_model.summary
training_sum.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---+--------------------+--------------------+----------+
#             features|sex|       rawPrediction|         probability|prediction|
# +--------------------+---+--------------------+--------------------+----------+
# [1950.0,0.0,7.0,1...|0.0|[21.6918862393261...|[0.99999999962039...|       0.0|
# [1950.0,0.0,10.0,...|0.0|[21.6922454656956...|[0.99999999962053...|       0.0|
# [1950.0,0.0,15.0,...|0.0|[21.6928195693829...|[0.99999999962074...|       0.0|
# [1950.0,0.0,33.0,...|0.0|[21.6949960860736...|[0.99999999962157...|       0.0|
# [1950.0,0.0,42.0,...|0.0|[21.6960709036982...|[0.99999999962197...|       0.0|
# [1950.0,0.0,62.0,...|0.0|[21.6984537132545...|[0.99999999962287...|       0.0|
# [1950.0,0.0,68.0,...|0.0|[21.6991731565073...|[0.99999999962314...|       0.0|
# [1950.0,0.0,95.0,...|0.0|[21.7023901530139...|[0.99999999962436...|       0.0|
# [1950.0,1.0,0.0,3...|1.0|[-22.634048632552...|[1.47964515255321...|       1.0|
# [1950.0,1.0,23.0,...|1.0|[-22.631253521599...|[1.48378671028441...|       1.0|
# [1950.0,1.0,25.0,...|1.0|[-22.630994181222...|[1.48417156599247...|       1.0|
# [1950.0,1.0,68.0,...|1.0|[-22.625862622258...|[1.49180725463232...|       1.0|
# [1950.0,1.0,76.0,...|1.0|[-22.624906317786...|[1.49323455894122...|       1.0|
# [1950.0,1.0,76.0,...|1.0|[-22.624907308299...|[1.49323307987264...|       1.0|
# [1950.0,1.0,85.0,...|1.0|[-22.623834361645...|[1.49483609913272...|       1.0|
# [1950.0,1.0,93.0,...|1.0|[-22.622881689057...|[1.49626086706937...|       1.0|
# [1951.0,0.0,2.0,2...|0.0|[21.7023656059203...|[0.99999999962435...|       0.0|
# [1951.0,0.0,5.0,2...|0.0|[21.7027330315423...|[0.99999999962448...|       0.0|
# [1951.0,0.0,20.0,...|0.0|[21.7045432506962...|[0.99999999962516...|       0.0|
# [1951.0,0.0,40.0,...|0.0|[21.7069440545849...|[0.99999999962606...|       0.0|
# +--------------------+---+--------------------+--------------------+----------+
# only showing top 20 rows
#
# </div>

# %%
training_sum.predictions.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+------------------+
# summary|               sex|        prediction|
# +-------+------------------+------------------+
#   count|           2141782|           2141782|
#    mean|0.5002647328252828|0.5002647328252828|
#  stddev|0.5000000466417818|0.5000000466417818|
#     min|               0.0|               0.0|
#     max|               1.0|               1.0|
# +-------+------------------+------------------+
#
# </div>

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pred_and_labels = fitted_sex_model.evaluate(test_sex)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pred_and_labels.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---+--------------------+--------------------+----------+
#             features|sex|       rawPrediction|         probability|prediction|
# +--------------------+---+--------------------+--------------------+----------+
# [1950.0,0.0,6.0,2...|  0|[21.6917333058220...|[0.99999999962033...|       0.0|
# [1950.0,0.0,9.0,2...|  0|[21.6920961090467...|[0.99999999962047...|       0.0|
# [1950.0,0.0,16.0,...|  0|[21.6929399810199...|[0.99999999962079...|       0.0|
# [1950.0,0.0,28.0,...|  0|[21.6943829396375...|[0.99999999962134...|       0.0|
# [1950.0,0.0,38.0,...|  0|[21.6955822134968...|[0.99999999962179...|       0.0|
# [1950.0,0.0,49.0,...|  0|[21.6968989824806...|[0.99999999962229...|       0.0|
# [1950.0,0.0,76.0,...|  0|[21.7001262418099...|[0.99999999962350...|       0.0|
# [1950.0,1.0,1.0,1...|  1|[-22.633869367892...|[1.47991042441497...|       1.0|
# [1950.0,1.0,82.0,...|  1|[-22.624191386873...|[1.49430250019356...|       1.0|
# [1950.0,1.0,89.0,...|  1|[-22.623357942808...|[1.49554843688064...|       1.0|
# [1951.0,0.0,17.0,...|  0|[21.7041820432992...|[0.99999999962503...|       0.0|
# [1951.0,0.0,18.0,...|  0|[21.7043250441518...|[0.99999999962508...|       0.0|
# [1951.0,1.0,21.0,...|  1|[-22.620372336546...|[1.50002022784020...|       1.0|
# [1951.0,1.0,30.0,...|  1|[-22.619290667868...|[1.50164363057008...|       1.0|
# [1951.0,1.0,35.0,...|  1|[-22.618676558433...|[1.50256608730808...|       1.0|
# [1951.0,1.0,39.0,...|  1|[-22.618198681339...|[1.50328430081758...|       1.0|
# [1951.0,1.0,46.0,...|  1|[-22.617372280927...|[1.50452712904900...|       1.0|
# [1951.0,1.0,62.0,...|  1|[-22.615453151101...|[1.50741728434077...|       1.0|
# [1952.0,0.0,39.0,...|  0|[21.7179577850686...|[0.99999999963016...|       0.0|
# [1952.0,0.0,67.0,...|  0|[21.7212994028955...|[0.99999999963139...|       0.0|
# +--------------------+---+--------------------+--------------------+----------+
# only showing top 20 rows
#
# </div>

# %%
sex_eval = BinaryClassificationEvaluator(rawPredictionCol='prediction',
                                           labelCol='sex')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auc = sex_eval.evaluate(pred_and_labels.predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: 1.0</div>
